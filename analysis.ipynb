# %% [markdown]
# # Insurance Cost Forecasting Model

# %% [markdown]
# ## Import libs

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import Datasets

# %%
# Loading Datasets
df = pd.read_csv("datasets/insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# Get Data Insights
#
# - Data Structure
# - Correlations (HeatMaps)
# - Time-series
# -

# %% [markdown]
# ### Data Structures

# %%
# Get gender count
males = (df["sex"] == "male").sum()
females = (df["sex"] == "female").sum()
gender = [males, females]

# Get smoker
smokers = (df["smoker"] == "yes").sum()
non_smokers = (df["smoker"] == "no").sum()
is_smoking = [smokers, non_smokers]

# Get number of children per person
children_counts = df["children"].value_counts().sort_index()
children_labels = children_counts.index.astype(str)
children_sizes = children_counts.values

# Get region count
region_counts = df["region"].value_counts().sort_index()
region_labels = region_counts.index.astype(str)
region_sizes = region_counts.values

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 5))

ax[0].pie(gender, labels=["males", "females"], autopct='%1.1f%%')
ax[0].set_title("Gender")

ax[1].pie(is_smoking, labels=["yes", "no"], autopct='%1.1f%%')
ax[1].set_title("Smokers")

ax[2].pie(children_sizes, labels=children_labels, autopct='%1.1f%%')
ax[2].set_title("Children")

ax[3].pie(region_sizes, labels=region_labels, autopct="%1.1f%%")
ax[3].set_title("Regions")

plt.show()

# %% [markdown]
# ## Data Pre-processing
#
# To get more insights on data like #correlation and #Heatmaps , we need to transform data into numerical values.
#
# Our dataset contains text-data ( #categorical-data ) which can be converted into numeric data using #feature-encoding
#
# To learn more on #feature-encoding refer to [[Feature Encoding]]
#
# As our dataset includes some #categorical-data -> sex, smoker, region. So we apply encoding techniques to transform these #features
#
# - sex -> #binary-encoding
# - smoker -> #binary-encoding
# - region -> #one-hot-encoding
#
# The region feature is divided into four categories, that's why it must be encoded with #one-hot-encoding to prevent priority to higher encoded category.

# %% [markdown]
# ### Binary Encoding
# This encoding is applied on Sex, Smoker feature

# %%
# Binary Encoding applied on sex, smoker

df["sex"] = df["sex"].map({"female": 0, "male": 1}).astype(bool)
df["smoker"] = df["smoker"].map({"no": 0, "yes": 1}).astype(bool)

df[["sex", "smoker"]].head()
# Out:
#      sex  smoker
# 0  False    True
# 1   True   False
# 2   True   False
# 3   True   False
# 4   True   False

# %% [markdown]
# ### One-Hot Encoding
# This encoding is applied on region feature

# %%
df["region"].nunique()
# Out:
# 4

# %%
# OHE applied on regions
df_copy_regions = df.copy()
df = pd.get_dummies(df, columns=["region"])
df.head()
# Out:
#    age    sex     bmi  children  smoker      charges  region_northeast  \
# 0   19  False  27.900         0    True  16884.92400             False
# 1   18   True  33.770         1   False   1725.55230             False
# 2   28   True  33.000         3   False   4449.46200             False
# 3   33   True  22.705         0   False  21984.47061             False
# 4   32   True  28.880         0   False   3866.85520             False
#
#    region_northwest  region_southeast  region_southwest
# 0             False             False              True
# 1             False              True             False
# 2             False              True             False
# 3              True             False             False
# 4              True             False             False

# %% [markdown]
# ### Correlations

# %%
# Calculate and display correlation matrix
corr = df.corr()

plt.figure(figsize=(10, 10))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Box-plot

# %%
df_plot = df.copy()
df_plot["smoker"] = df_plot["smoker"].map({False: "no", True: "yes"})

plt.figure(figsize=(12, 6))
sns.boxplot(x="smoker", y="charges", data=df_plot, palette="Set2")
plt.title("Charges by Smoker Status (Box Plot)")
plt.xlabel("Smoker")
plt.ylabel("Charges")
plt.show()

plt.figure(figsize=(12, 6))
sns.violinplot(x="smoker", y="charges", data=df_plot, inner="quartile", palette="Set2")
plt.title("Charges by Smoker Status (Violin Plot)")
plt.xlabel("Smoker")
plt.ylabel("Charges")
plt.show()
# Out:
# C:\Users\VICTUS\AppData\Local\Temp\ipykernel_1184\4019313712.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="smoker", y="charges", data=df_plot, palette="Set2")
# C:\Users\VICTUS\AppData\Local\Temp\ipykernel_1184\4019313712.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="smoker", y="charges", data=df_plot, inner="quartile", palette="Set2")

# %% [markdown]
# The above graphs shows us how much charges differ for smoker(~35000) and non-smoker(~9000)

# %% [markdown]
# ### Scatter plot

# %% [markdown]
# **Scatter plot by Smoker Status**

# %%
# Scatter of BMI vs Chargers by Smoker status

plt.figure(figsize=(10, 6))
plt.scatter(
    x=df.loc[df["smoker"], "bmi"],
    y=df.loc[df["smoker"], "charges"],
    c="red",
    s=10,
    label="smoker"
)

plt.scatter(
    x=df.loc[~df["smoker"], "bmi"],
    y=df.loc[~df["smoker"], "charges"],
    c="blue",
    s=10,
    label="non-smoker"
)

plt.xlabel("BMI")
plt.ylabel("Charges")
plt.title("BMI vs Charges by Smoker Status")
plt.legend()
plt.show()

# %% [markdown]
# The above graph shows clear difference between chargers applied to smokers and non-smokers

# %% [markdown]
# **Scatter Plot by region located**

# %%
# Scatter of BMI vs Chargers by Region

plt.figure(figsize=(12, 8))
sns.scatterplot(
    x="bmi",
    y="charges",
    hue="region",
    data=df_copy_regions,
    palette="Set2",
    edgecolor="w",
    s=10,
)
plt.title("BMI vs Charges by Region")
plt.xlabel("BMI")
plt.ylabel("Charges")
plt.legend(title="Region")
plt.show()

# %% [markdown]
# The above graph shows there no clear difference between people with different regions

# %% [markdown]
# ### Data Scaling and Normalization
